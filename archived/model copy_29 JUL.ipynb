# %%
from pyomo.environ import *
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from dash import Dash, dcc, html
import webbrowser
from threading import Timer
import dash_bootstrap_components as dbc
import plotly.io as pio
from dash.dependencies import Input, Output
import json
from scripts.result_export import generate_html
from scripts.price_process import price_process

# %% [markdown]
# # Read Data

# %%
excel_mode = 2

# %%
if excel_mode == 1:
    # Read price data from Excel
    price_data = pd.read_excel('data/price_data.xlsx', sheet_name= None, index_col=0)

    data = price_data

    # Iteratively merge all dataframes on 'Timestamp'
    price_df = pd.DataFrame(index =  data[list(data.keys())[0]].index)

    for key in data:
        price_df = pd.concat([price_df, data[key]], axis = 1)

    model_time_period = 24    # periods
    dt = 1

# %%
if excel_mode != 1:
    dir_path = 'data/prices/'
    prim_category = 'PRIRESC'
    cons_category = 'CONRESC'

    price_df = price_process(dir_path, prim_category, cons_category)

    model_time_period = 48    # periods
    dt = 0.5
# Out:
# Found 12 CSV files in data/prices/energy/
# Found 12 CSV files in data/prices/regulation/
# Found 12 CSV files in data/prices/reserve/

# %%
# Parameters
schedule_data = pd.read_excel('data/schedule_data_s1.xlsx', sheet_name= None, index_col=0)

λ_min = schedule_data['soc_limit']['min']
λ_max = schedule_data['soc_limit']['max']
theta = schedule_data['availability']

z = {}
s = {}
z['arb'], z['reg'], z['pres'], z['cres'], z['opp'] = schedule_data['basis'].value.values
s['reg'] = schedule_data['basis'].loc['regulation', 'sym']

# %%
filename = "test"

z['opp'] = 0
# s['reg'] = 1

cap_power = 1  # Example value
cap_energy = 4  # Example value

Seff = 0.9995
Ceff = 0.9
Deff = 0.9


λ_0 = 0.5
initial_soc = λ_0 * cap_energy

kappa = 0.95     # regulation performance score
beta = 0.15       # activated portion for reserve


cycle_life = 3650
calendar_life = 10
total_time_period = len(price_df)
num_slices = int(total_time_period // model_time_period)     # number of time slices to model

η = cycle_life/calendar_life/365                 # number of cycle per time slice

# %% [markdown]
# # Model

# %%
def optimize_revenue(initial_soc, price_vector, current_period, first_period, last_period):

    # Define the model
    model = ConcreteModel()

    # Price Data for the day
    total_time_period = len(price_vector)

    T = range(1, total_time_period + 1)
    SOC_T = range(0, total_time_period + 1)

    p_arb = {t: price_vector['arb_energy_price'].values[t-1] for t in T}
    p_pres = {t: price_vector['pres_capacity_price'].values[t-1] for t in T}
    p_cres = {t: price_vector['cres_capacity_price'].values[t-1] for t in T}

    # p_reg = {t: price_vector['reg_capacity_price'].values[t-1] for t in T}
    p_reg_down = {t: price_vector['reg_down_price'].values[t-1] for t in T}
    p_reg_up = {t: price_vector['reg_up_price'].values[t-1] for t in T}

    start_soc = λ_0 * cap_energy

    # Variables
    model.SOC = Var(SOC_T, within=NonNegativeReals, bounds = (0, cap_energy))
 
    model.C_arb = Var(T, within=NonNegativeReals, bounds = (0, cap_power))
    model.D_arb = Var(T, within=NonNegativeReals, bounds = (0, cap_power))
    model.C_reg = Var(T, within=NonNegativeReals, bounds = (0, cap_power * 2))
    model.D_reg = Var(T, within=NonNegativeReals, bounds = (0, cap_power * 2))
    model.D_pres = Var(T, within=NonNegativeReals, bounds = (0, cap_power * 2))
    model.D_cres = Var(T, within=NonNegativeReals, bounds = (0, cap_power * 2))

    model.y_ch = Var(T, within=Binary)
    model.y_minus = Var(T, within=Binary)

    model.R_arb = Var(T, within=Reals)
    model.R_reg = Var(T, within=Reals)
    model.R_pres = Var(T, within=Reals)
    model.R_cres = Var(T, within=Reals)

    # Objective function
    model.obj = Objective(
        expr= sum(model.R_arb[t] + model.R_reg[t] + model.R_pres[t] + model.R_cres[t] for t in T),        
        sense=maximize
    )

    def revenue_arbitrage_rule(model, t):
        return model.R_arb[t] == p_arb[t]  * (model.D_arb[t] - model.C_arb[t]) * dt
    model.revenue_arbitrage = Constraint(T, rule=revenue_arbitrage_rule)

    def revenue_primary_reserve_rule(model, t):
        return model.R_pres[t] == p_pres[t]  * model.D_pres[t] * dt
    model.revenue_preserve = Constraint(T, rule=revenue_primary_reserve_rule)

    def revenue_contingency_reserve_rule(model, t):
        return model.R_cres[t] == p_cres[t]  * model.D_cres[t] * dt
    model.revenue_creserve = Constraint(T, rule=revenue_contingency_reserve_rule)

    # Arbitrage Constraints

    def c_limit_constraint(model, t):
        return model.C_arb[t] <= cap_power #* model.y_ch[t]
    model.C_limit = Constraint(T, rule=c_limit_constraint)

    def d_limit_constraint(model, t):
        return model.D_arb[t]  <= cap_power #* (1 - model.y_ch[t])
    model.D_limit = Constraint(T, rule=d_limit_constraint)

    def soc_constraints(model, t):
        if t == 0:
            return model.SOC[t] == initial_soc
        else:
            return model.SOC[t] == model.SOC[t-1] * Seff + ((model.C_arb[t] + 0.15 * model.C_reg[t]) * Ceff - (model.D_arb[t] + 0.15 * model.D_reg[t])/Deff) * dt
            # return model.SOC[t] == model.SOC[t-1] * Seff + (model.C_arb[t]  * Ceff - model.D_arb[t]/Deff) * dt
    model.SOC_constraints = Constraint(SOC_T, rule=soc_constraints)

    def soc_lower_limit_constraint(model, t):
        return model.SOC[t] >= cap_energy * λ_min[t]
    model.SOC_lower_limit = Constraint(T, rule=soc_lower_limit_constraint)

    def soc_upper_limit_constraint(model, t):
        return model.SOC[t] <= cap_energy * λ_max[t]
    model.SOC_upper_limit = Constraint(T, rule=soc_upper_limit_constraint)

    if current_period == last_period:
        def soc_final_state_constraint(model):
            end_t = SOC_T[-1]
            return model.SOC[end_t] == start_soc 
        model.SOC_final = Constraint(rule=soc_final_state_constraint)


    def soc_reg_down_rule(model, t):
        return model.SOC[t] + 0 * model.C_reg[t] * Ceff * dt <= cap_energy
    model.soc_reg_down = Constraint(T, rule=soc_reg_down_rule)

    def soc_reg_up_rule(model, t):
        return model.SOC[t] >= (0 * model.D_reg[t] + model.D_pres[t] + model.D_cres[t])/Deff * dt
    model.soc_reg_up = Constraint(T, rule=soc_reg_up_rule)

    if s['reg'] == 1:
        def reg_constraint_rule(model, t):
            return model.C_reg[t] == model.D_reg[t]
        model.reg_up_down = Constraint(T, rule=reg_constraint_rule)

        def revenue_regulation_rule(model, t):
            return model.R_reg[t] == kappa * (p_reg_up[t] * model.D_reg[t]) * dt
        model.revenue_regulation = Constraint(T, rule=revenue_regulation_rule)

    else:

        def revenue_regulation_rule(model, t):
            return model.R_reg[t] == kappa * (p_reg_down[t] * model.C_reg[t] + p_reg_up[t] * model.D_reg[t]) * dt + kappa * beta * (p_arb[t] * model.D_reg[t] - p_arb[t] * model.C_reg[t]) * dt
        model.revenue_regulation = Constraint(T, rule=revenue_regulation_rule)


    if z['opp'] == 0:
        def total_charge_rule(model, t):
            return model.C_reg[t]  + model.C_arb[t]  <= cap_power * model.y_minus[t]
        model.total_charge = Constraint(T, rule=total_charge_rule)

        def total_discharge_rule(model, t):
            return model.D_reg[t] + model.D_arb[t] +  model.D_pres[t] +  model.D_cres[t] <= cap_power * (1 - model.y_minus[t])
        model.total_discharge = Constraint(T, rule=total_discharge_rule)

    elif z['opp'] == 1: 

        def total_charge_rule(model, t):
            return model.C_reg[t] - (model.D_arb[t] - model.C_arb[t])  <= cap_power 
        model.total_charge = Constraint(T, rule=total_charge_rule)

        def total_discharge_rule(model, t):
            return model.D_reg[t] + (model.D_arb[t] - model.C_arb[t]) +  model.D_pres[t] +  model.D_cres[t] <= cap_power 
        model.total_discharge = Constraint(T, rule=total_discharge_rule)

    else:

        def total_charge_rule(model, t):
            return model.C_reg[t] + model.C_arb[t] - model.D_arb[t] <= cap_power * model.y_ch[t]
        model.total_charge = Constraint(T, rule=total_charge_rule)

        def total_discharge_rule(model, t):
            return model.D_reg[t]  + model.D_arb[t] +  model.D_pres[t] +  model.D_cres[t] - model.C_arb[t] <= cap_power * (1 - model.y_ch[t])
        model.total_discharge = Constraint(T, rule=total_discharge_rule)

        # def total_charge_rule2(model, t):
        #     return model.C_reg[t] + model.C_arb[t]  <= cap_power 
        # model.total_charge2 = Constraint(T, rule=total_charge_rule2)

        # def total_discharge_rule2(model, t):
        #     return model.D_reg[t] + model.D_arb[t]  +  model.D_pres[t] +  model.D_cres[t] <= cap_power 
        # model.total_discharge2 = Constraint(T, rule=total_discharge_rule2)


    # Service availability

    def arbitrage_availability_rule(model, t):
        return model.C_arb[t] + model.D_arb[t] <= cap_power * z['arb'] * theta['arb'].loc[t] * 10
    model.arbitrage_availability = Constraint(T, rule=arbitrage_availability_rule)

    def regulation_availability_rule(model, t):
        return model.C_reg[t] + model.D_reg[t] <= cap_power * z['reg'] * theta['reg'].loc[t] * 10
    model.regulation_availability = Constraint(T, rule=regulation_availability_rule)

    def preserve_availability_rule(model, t):
        return model.D_pres[t] <= cap_power * z['pres'] * theta['pres'].loc[t] * 10
    model.preserve_availability = Constraint(T, rule=preserve_availability_rule)

    def creserve_availability_rule(model, t):
        return model.D_cres[t] <= cap_power * z['cres'] * theta['cres'].loc[t] * 10
    model.creserve_availability = Constraint(T, rule=creserve_availability_rule)


    # Cycle limits

    def energy_cap_C_constraint(model):
        return sum(model.C_arb[t] +  model.C_reg[t]*beta for t in T)*dt <= η * cap_energy
        # return sum(model.C_arb[t] for t in T)*dt <= η * cap_energy
    model.energy_cap_C = Constraint(rule=energy_cap_C_constraint)

    def energy_cap_D_constraint(model):
        return sum(model.D_arb[t] + model.D_reg[t]*beta for t in T)*dt <= η * cap_energy
        # return sum(model.D_arb[t] for t in T)*dt <= η * cap_energy
    model.energy_cap_D = Constraint(rule=energy_cap_D_constraint)


    # Solve the model
    solver = SolverFactory('gurobi_direct')
    solver.options['mipgap'] = 0.1  # 1% optimality tolerance
    # solver.options['tmlim'] = 600    # 10 minutes time limit
    solver.solve(model, tee=True)

    # Extract results for charging, discharging, and SOC
    charging_schedule = [model.C_arb[t].value for t in T]  # Charging as negative
    discharging_schedule = [model.D_arb[t].value for t in T]  # Discharging as positive
    reg_down_schedule = [model.C_reg[t].value for t in T]  # Charging as negative
    reg_up_schedule = [model.D_reg[t].value for t in T]  # Discharging as positive
    pres_schedule = [model.D_pres[t].value for t in T]  # Charging as negative
    cres_schedule = [model.D_cres[t].value for t in T]  # Discharging as positive

    soc_schedule = [model.SOC[t].value for t in SOC_T]  # State of Charge

    rev_arbitrage =  sum(model.R_arb[t] for t in T)() 
    rev_regulation = sum(model.R_reg[t] for t in T)() 
    rev_prim_reserve = sum(model.R_pres[t] for t in T)() 
    rev_cont_reserve = sum(model.R_cres[t] for t in T)() 

    # Return the results and final SOC
    return model.obj(), [charging_schedule, discharging_schedule, soc_schedule, reg_down_schedule, reg_up_schedule, pres_schedule, cres_schedule], [rev_arbitrage, rev_regulation, rev_prim_reserve, rev_cont_reserve]

# %% [markdown]
# # Run

# %%
# Lists to store results
total_revenue = 0
arbitrage = 0
regulation = 0
preserve = 0
creserve = 0

all_charging_schedules = []
all_discharging_schedules = []
all_reg_down_schedules = []
all_reg_up_schedules = []
all_pres_schedules = []
all_cres_schedules = []
all_soc_schedules = []

first_p = 0
last_p = num_slices #- 1

# Run the optimization for each time period
for p in range(num_slices):
    if p < 370:
        print("watch", p)
        periodic_price = price_df[p*model_time_period:(p+1)*model_time_period]
        revenue, [charging_schedule, discharging_schedule, soc_schedule, reg_down_schedule, reg_up_schedule, pres_schedule, cres_schedule], [rev_arbitrage, rev_regulation, rev_prim_reserve, rev_cont_reserve] = optimize_revenue(initial_soc, periodic_price, p, first_p, last_p)
        final_soc = soc_schedule[-1]
        
        # Store the results
        total_revenue += revenue
        arbitrage += rev_arbitrage
        regulation += rev_regulation
        preserve += rev_prim_reserve
        creserve += rev_cont_reserve

        all_charging_schedules.extend(charging_schedule)
        all_discharging_schedules.extend(discharging_schedule)
        all_reg_down_schedules.extend(reg_down_schedule)
        all_reg_up_schedules.extend(reg_up_schedule)
        all_pres_schedules.extend(pres_schedule)
        all_cres_schedules.extend(cres_schedule)
        all_soc_schedules.extend(soc_schedule[:-1])

        # Update the initial SOC for the next day
        initial_soc = final_soc

print(total_revenue)
# Out:
# watch 0
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0xdcac4831
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 1e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 674 rows and 386 columns
# Presolve time: 0.01s
# Presolved: 145 rows, 239 columns, 621 nonzeros
# Variable types: 191 continuous, 48 integer (48 binary)
# Found heuristic solution: objective 269.4384147
#
# Root relaxation: objective 5.750420e+02, 127 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  575.04197    0   10  269.43841  575.04197   113%     -    0s
# H    0     0                     568.7990178  575.04197  1.10%     -    0s
#
# Explored 1 nodes (129 simplex iterations) in 0.52 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 568.799 269.438
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 5.687990177565e+02, best bound 5.750419696110e+02, gap 1.0976%
# watch 1
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0xc127decc
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 674 rows and 388 columns
# Presolve time: 0.00s
# Presolved: 145 rows, 237 columns, 615 nonzeros
# Variable types: 190 continuous, 47 integer (47 binary)
# Found heuristic solution: objective 68.1524381
#
# Root relaxation: objective 6.473391e+02, 161 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  647.33914    0    5   68.15244  647.33914   850%     -    0s
# H    0     0                     642.4291044  647.33914  0.76%     -    0s
#
# Explored 1 nodes (161 simplex iterations) in 0.13 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 642.429 68.1524
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 6.424291044155e+02, best bound 6.473391424640e+02, gap 0.7643%
# watch 2
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0x52558cdd
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 674 rows and 388 columns
# Presolve time: 0.00s
# Presolved: 145 rows, 237 columns, 615 nonzeros
# Variable types: 190 continuous, 47 integer (47 binary)
# Found heuristic solution: objective 213.9107177
#
# Root relaxation: objective 7.810761e+02, 122 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  781.07609    0    7  213.91072  781.07609   265%     -    0s
# H    0     0                     768.6394689  781.07609  1.62%     -    0s
#
# Explored 1 nodes (122 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 768.639 213.911
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 7.686394689022e+02, best bound 7.810760870304e+02, gap 1.6180%
# watch 3
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0x9fc538e8
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 674 rows and 388 columns
# Presolve time: 0.00s
# Presolved: 145 rows, 237 columns, 615 nonzeros
# Variable types: 190 continuous, 47 integer (47 binary)
# Found heuristic solution: objective 293.9038194
#
# Root relaxation: objective 9.523436e+02, 136 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  952.34355    0    8  293.90382  952.34355   224%     -    0s
# H    0     0                     926.0522080  952.34355  2.84%     -    0s
#
# Explored 1 nodes (136 simplex iterations) in 0.11 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 926.052 293.904
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 9.260522079762e+02, best bound 9.523435539591e+02, gap 2.8391%
# watch 4
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0xfe89d8e7
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 3e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 674 rows and 388 columns
# Presolve time: 0.00s
# Presolved: 145 rows, 237 columns, 615 nonzeros
# Variable types: 190 continuous, 47 integer (47 binary)
# Found heuristic solution: objective 888.7867177
#
# Root relaxation: objective 2.631332e+03, 140 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2631.33194    0    6  888.78672 2631.33194   196%     -    0s
# H    0     0                    2604.3948165 2631.33194  1.03%     -    0s
#
# Explored 1 nodes (140 simplex iterations) in 0.11 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 2604.39 888.787
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 2.604394816504e+03, best bound 2.631331942755e+03, gap 1.0343%
# watch 5
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0x4ddea47d
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 4e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 6.0947133
# Presolve removed 673 rows and 385 columns
# Presolve time: 0.00s
# Presolved: 146 rows, 240 columns, 623 nonzeros
# Found heuristic solution: objective 183.8510467
# Variable types: 192 continuous, 48 integer (48 binary)
#
# Root relaxation: objective 1.538870e+03, 159 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1538.86984    0   12  183.85105 1538.86984   737%     -    0s
# H    0     0                    1520.1292364 1538.86984  1.23%     -    0s
#
# Explored 1 nodes (159 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 3: 1520.13 183.851 6.09471
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.520129236423e+03, best bound 1.538869839993e+03, gap 1.2328%
# watch 6
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0x9cd408be
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 674 rows and 388 columns
# Presolve time: 0.00s
# Presolved: 145 rows, 237 columns, 615 nonzeros
# Variable types: 190 continuous, 47 integer (47 binary)
# Found heuristic solution: objective 72.3315573
#
# Root relaxation: objective 5.434962e+02, 145 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  543.49619    0    7   72.33156  543.49619   651%     -    0s
# H    0     0                     531.3874465  543.49619  2.28%     -    0s
#
# Explored 1 nodes (145 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 531.387 72.3316
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 5.313874464592e+02, best bound 5.434961941825e+02, gap 2.2787%
# watch 7
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0x915eb6b6
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 4e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 674 rows and 388 columns
# Presolve time: 0.00s
# Presolved: 145 rows, 237 columns, 615 nonzeros
# Variable types: 190 continuous, 47 integer (47 binary)
# Found heuristic solution: objective 224.9145562
#
# Root relaxation: objective 1.286501e+03, 142 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1286.50079    0   10  224.91456 1286.50079   472%     -    0s
# H    0     0                    1252.4410114 1286.50079  2.72%     -    0s
#
# Explored 1 nodes (143 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 1252.44 224.915
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.252441011437e+03, best bound 1.286500792680e+03, gap 2.7195%
# watch 8
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0x08fe6381
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 2e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 674 rows and 388 columns
# Presolve time: 0.00s
# Presolved: 145 rows, 237 columns, 615 nonzeros
# Variable types: 190 continuous, 47 integer (47 binary)
# Found heuristic solution: objective 2042.7394819
#
# Root relaxation: objective 9.928137e+03, 172 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 9928.13746    0    6 2042.73948 9928.13746   386%     -    0s
# H    0     0                    9878.9822032 9928.13746  0.50%     -    0s
#
# Explored 1 nodes (172 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 9878.98 2042.74
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 9.878982203176e+03, best bound 9.928137463269e+03, gap 0.4976%
# watch 9
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0x24ec5c96
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 3e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 674 rows and 388 columns
# Presolve time: 0.00s
# Presolved: 145 rows, 237 columns, 615 nonzeros
# Variable types: 190 continuous, 47 integer (47 binary)
# Found heuristic solution: objective 305.8199946
#
# Root relaxation: objective 9.249683e+02, 145 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  924.96831    0    3  305.81999  924.96831   202%     -    0s
# H    0     0                     921.8385705  924.96831  0.34%     -    0s
#
# Explored 1 nodes (145 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 921.839 305.82
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 9.218385705405e+02, best bound 9.249683088608e+02, gap 0.3395%
# watch 10
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0x302dbd4c
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 674 rows and 388 columns
# Presolve time: 0.00s
# Presolved: 145 rows, 237 columns, 615 nonzeros
# Variable types: 190 continuous, 47 integer (47 binary)
# Found heuristic solution: objective 193.1962857
#
# Root relaxation: objective 1.065349e+03, 136 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1065.34911    0    6  193.19629 1065.34911   451%     -    0s
# H    0     0                    1062.7888393 1065.34911  0.24%     -    0s
#
# Explored 1 nodes (136 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 1062.79 193.196
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.062788839279e+03, best bound 1.065349113666e+03, gap 0.2409%
# watch 11
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0xd3a81e76
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 674 rows and 388 columns
# Presolve time: 0.00s
# Presolved: 145 rows, 237 columns, 615 nonzeros
# Variable types: 190 continuous, 47 integer (47 binary)
# Found heuristic solution: objective 161.6278696
#
# Root relaxation: objective 9.137029e+02, 144 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  913.70289    0   10  161.62787  913.70289   465%     -    0s
# H    0     0                     875.4056575  913.70289  4.37%     -    0s
#
# Explored 1 nodes (144 simplex iterations) in 0.11 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 875.406 161.628
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 8.754056574551e+02, best bound 9.137028893540e+02, gap 4.3748%
# watch 12
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0xd66672c0
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 674 rows and 388 columns
# Presolve time: 0.00s
# Presolved: 145 rows, 237 columns, 615 nonzeros
# Variable types: 190 continuous, 47 integer (47 binary)
# Found heuristic solution: objective 201.8041668
#
# Root relaxation: objective 9.587557e+02, 132 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  958.75568    0    6  201.80417  958.75568   375%     -    0s
# H    0     0                     941.7417932  958.75568  1.81%     -    0s
#
# Explored 1 nodes (132 simplex iterations) in 0.12 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 941.742 201.804
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 9.417417931567e+02, best bound 9.587556817036e+02, gap 1.8066%
# watch 13
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0x4d21368b
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 1e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 674 rows and 388 columns
# Presolve time: 0.01s
# Presolved: 145 rows, 237 columns, 615 nonzeros
# Variable types: 190 continuous, 47 integer (47 binary)
# Found heuristic solution: objective 113.6519701
#
# Root relaxation: objective 4.565530e+02, 131 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  456.55303    0    2  113.65197  456.55303   302%     -    0s
# H    0     0                     455.8716669  456.55303  0.15%     -    0s
#
# Explored 1 nodes (131 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 455.872 113.652
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 4.558716669007e+02, best bound 4.565530257926e+02, gap 0.1495%
# watch 14
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0x410866ca
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective -1.0612667
# Presolve removed 674 rows and 388 columns
# Presolve time: 0.00s
# Presolved: 145 rows, 237 columns, 615 nonzeros
# Found heuristic solution: objective -0.9012667
# Variable types: 190 continuous, 47 integer (47 binary)
#
# Root relaxation: objective 6.242950e+02, 152 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  624.29500    0   11   -0.90127  624.29500      -     -    0s
# H    0     0                     608.8516138  624.29500  2.54%     -    0s
#
# Explored 1 nodes (152 simplex iterations) in 0.11 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 3: 608.852 -0.901267 -1.06127
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 6.088516137929e+02, best bound 6.242949978535e+02, gap 2.5365%
# watch 15
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0xe4a6618c
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 674 rows and 388 columns
# Presolve time: 0.00s
# Presolved: 145 rows, 237 columns, 615 nonzeros
# Variable types: 190 continuous, 47 integer (47 binary)
# Found heuristic solution: objective 192.4984214
#
# Root relaxation: objective 8.007017e+02, 147 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  800.70167    0    9  192.49842  800.70167   316%     -    0s
# H    0     0                     769.4295743  800.70167  4.06%     -    0s
#
# Explored 1 nodes (147 simplex iterations) in 0.11 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 769.43 192.498
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 7.694295742748e+02, best bound 8.007016744925e+02, gap 4.0643%
# watch 16
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0xec9098e4
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 2e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 674 rows and 388 columns
# Presolve time: 0.00s
# Presolved: 145 rows, 237 columns, 615 nonzeros
# Variable types: 190 continuous, 47 integer (47 binary)
# Found heuristic solution: objective 1738.5497569
#
# Root relaxation: objective 5.003320e+03, 122 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5003.32045    0    7 1738.54976 5003.32045   188%     -    0s
# H    0     0                    4990.4276675 5003.32045  0.26%     -    0s
#
# Explored 1 nodes (122 simplex iterations) in 0.08 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 4990.43 1738.55
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 4.990427667532e+03, best bound 5.003320445181e+03, gap 0.2584%
# watch 17
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0x12f5e1f6
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 674 rows and 388 columns
# Presolve time: 0.00s
# Presolved: 145 rows, 237 columns, 615 nonzeros
# Variable types: 190 continuous, 47 integer (47 binary)
# Found heuristic solution: objective 216.2955736
#
# Root relaxation: objective 7.934340e+02, 131 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  793.43402    0    7  216.29557  793.43402   267%     -    0s
# H    0     0                     778.3873573  793.43402  1.93%     -    0s
#
# Explored 1 nodes (131 simplex iterations) in 0.08 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 778.387 216.296
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 7.783873573263e+02, best bound 7.934340219863e+02, gap 1.9331%
# watch 18
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0x993d3e8b
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 674 rows and 388 columns
# Presolve time: 0.00s
# Presolved: 145 rows, 237 columns, 615 nonzeros
# Variable types: 190 continuous, 47 integer (47 binary)
# Found heuristic solution: objective 112.2542920
#
# Root relaxation: objective 5.069994e+02, 103 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  506.99940    0    7  112.25429  506.99940   352%     -    0s
# H    0     0                     498.7227949  506.99940  1.66%     -    0s
#
# Explored 1 nodes (103 simplex iterations) in 0.10 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 498.723 112.254
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 4.987227948646e+02, best bound 5.069993980614e+02, gap 1.6596%
# watch 19
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0xab73dfa6
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 1e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective -0.1781156
# Presolve removed 674 rows and 388 columns
# Presolve time: 0.00s
# Presolved: 145 rows, 237 columns, 615 nonzeros
# Found heuristic solution: objective 0.0718844
# Variable types: 190 continuous, 47 integer (47 binary)
#
# Root relaxation: objective 5.589625e+02, 135 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  558.96250    0    5    0.07188  558.96250      -     -    0s
# H    0     0                     549.3223350  558.96250  1.75%     -    0s
#
# Explored 1 nodes (135 simplex iterations) in 0.10 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 3: 549.322 0.0718844 -0.178116
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 5.493223349766e+02, best bound 5.589625003458e+02, gap 1.7549%
# watch 20
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0xcb1bbd4c
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 1e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 674 rows and 388 columns
# Presolve time: 0.00s
# Presolved: 145 rows, 237 columns, 615 nonzeros
# Variable types: 190 continuous, 47 integer (47 binary)
# Found heuristic solution: objective 116.6622234
#
# Root relaxation: objective 5.708111e+02, 126 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     570.8110975  570.81110  0.00%     -    0s
#
# Explored 1 nodes (126 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 570.811 116.662
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 5.708110974576e+02, best bound 5.708110974576e+02, gap 0.0000%
# watch 21
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0xeecb224b
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 1e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 1.9858459
# Presolve removed 674 rows and 388 columns
# Presolve time: 0.00s
# Presolved: 145 rows, 237 columns, 615 nonzeros
# Found heuristic solution: objective 2.0508459
# Variable types: 190 continuous, 47 integer (47 binary)
#
# Root relaxation: objective 3.544202e+02, 133 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  354.42019    0   11    2.05085  354.42019      -     -    0s
# H    0     0                     354.2001838  354.42019  0.06%     -    0s
#
# Explored 1 nodes (133 simplex iterations) in 0.10 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 3: 354.2 2.05085 1.98585
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 3.542001837584e+02, best bound 3.544201905320e+02, gap 0.0621%
# watch 22
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0x1f57f4b5
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 7e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 674 rows and 388 columns
# Presolve time: 0.00s
# Presolved: 145 rows, 237 columns, 615 nonzeros
# Variable types: 190 continuous, 47 integer (47 binary)
# Found heuristic solution: objective 94.0988743
#
# Root relaxation: objective 2.943713e+02, 140 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  294.37129    0    4   94.09887  294.37129   213%     -    0s
# H    0     0                     293.3188757  294.37129  0.36%     -    0s
#
# Explored 1 nodes (140 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 293.319 94.0989
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 2.933188756667e+02, best bound 2.943712913848e+02, gap 0.3588%
# watch 23
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0x8fb07269
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 1e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 674 rows and 388 columns
# Presolve time: 0.00s
# Presolved: 145 rows, 237 columns, 615 nonzeros
# Variable types: 190 continuous, 47 integer (47 binary)
# Found heuristic solution: objective 105.0471569
#
# Root relaxation: objective 3.833379e+02, 132 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  383.33792    0    5  105.04716  383.33792   265%     -    0s
# H    0     0                     370.0780649  383.33792  3.58%     -    0s
#
# Explored 1 nodes (132 simplex iterations) in 0.09 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 370.078 105.047
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 3.700780648814e+02, best bound 3.833379241224e+02, gap 3.5830%
# watch 24
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0xa87fc199
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 674 rows and 388 columns
# Presolve time: 0.00s
# Presolved: 145 rows, 237 columns, 615 nonzeros
# Variable types: 190 continuous, 47 integer (47 binary)
# Found heuristic solution: objective 180.4306261
#
# Root relaxation: objective 8.013670e+02, 131 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  801.36702    0    8  180.43063  801.36702   344%     -    0s
# H    0     0                     774.7366508  801.36702  3.44%     -    0s
#
# Explored 1 nodes (131 simplex iterations) in 0.10 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 774.737 180.431
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 7.747366508114e+02, best bound 8.013670166675e+02, gap 3.4373%
# watch 25
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0x538f8fcb
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 5e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 673 rows and 385 columns
# Presolve time: 0.00s
# Presolved: 146 rows, 240 columns, 623 nonzeros
# Variable types: 192 continuous, 48 integer (48 binary)
# Found heuristic solution: objective 336.9488950
#
# Root relaxation: objective 1.743730e+03, 135 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1743.72967    0    7  336.94890 1743.72967   418%     -    0s
# H    0     0                    1717.1595755 1743.72967  1.55%     -    0s
#
# Explored 1 nodes (135 simplex iterations) in 0.08 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 1717.16 336.949
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.717159575546e+03, best bound 1.743729668719e+03, gap 1.5473%
# watch 26
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0x69ced072
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 1e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 673 rows and 385 columns
# Presolve time: 0.00s
# Presolved: 146 rows, 240 columns, 623 nonzeros
# Variable types: 192 continuous, 48 integer (48 binary)
# Found heuristic solution: objective 110.5827090
#
# Root relaxation: objective 8.934936e+02, 152 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  893.49357    0    6  110.58271  893.49357   708%     -    0s
# H    0     0                     866.1803877  893.49357  3.15%     -    0s
#
# Explored 1 nodes (152 simplex iterations) in 0.09 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 866.18 110.583
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 8.661803877370e+02, best bound 8.934935708409e+02, gap 3.1533%
# watch 27
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0x9e652ec4
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 1e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 7.3391835
# Presolve removed 673 rows and 385 columns
# Presolve time: 0.00s
# Presolved: 146 rows, 240 columns, 623 nonzeros
# Found heuristic solution: objective 7.4254814
# Variable types: 192 continuous, 48 integer (48 binary)
#
# Root relaxation: objective 5.280011e+02, 148 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  528.00111    0    5    7.42548  528.00111  7011%     -    0s
# H    0     0                     496.1962849  528.00111  6.41%     -    0s
#
# Explored 1 nodes (148 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 3: 496.196 7.42548 7.33918
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 4.961962849488e+02, best bound 5.280011120525e+02, gap 6.4097%
# watch 28
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0x1fb6eb24
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 6e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 673 rows and 385 columns
# Presolve time: 0.00s
# Presolved: 146 rows, 240 columns, 623 nonzeros
# Variable types: 192 continuous, 48 integer (48 binary)
# Found heuristic solution: objective 83.6691889
#
# Root relaxation: objective 5.294417e+02, 145 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     529.4416604  529.44166  0.00%     -    0s
#
# Explored 1 nodes (145 simplex iterations) in 0.08 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 529.442 83.6692
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 5.294416604198e+02, best bound 5.294416604198e+02, gap 0.0000%
# watch 29
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0x5611abdb
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 1e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 674 rows and 388 columns
# Presolve time: 0.00s
# Presolved: 145 rows, 237 columns, 615 nonzeros
# Variable types: 190 continuous, 47 integer (47 binary)
# Found heuristic solution: objective 104.0949299
#
# Root relaxation: objective 7.083410e+02, 123 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  708.34101    0    7  104.09493  708.34101   580%     -    0s
# H    0     0                     695.1509000  708.34101  1.90%     -    0s
#
# Explored 1 nodes (123 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 695.151 104.095
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 6.951508999811e+02, best bound 7.083410056978e+02, gap 1.8974%
# watch 30
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0xb20d6b53
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 1e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 673 rows and 385 columns
# Presolve time: 0.00s
# ...
# Thread count was 20 (of 20 available processors)
#
# Solution count 3: 400.327 12.3837 6.51679
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 4.003269152488e+02, best bound 4.012966732527e+02, gap 0.2422%
# watch 344
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0xd136f124
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 9e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 674 rows and 388 columns
# Presolve time: 0.00s
# Presolved: 145 rows, 237 columns, 615 nonzeros
# Variable types: 190 continuous, 47 integer (47 binary)
# Found heuristic solution: objective 129.4213383
#
# Root relaxation: objective 6.398790e+02, 154 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  639.87905    0    7  129.42134  639.87905   394%     -    0s
# H    0     0                     618.8364526  639.87905  3.40%     -    0s
#
# Explored 1 nodes (154 simplex iterations) in 0.09 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 618.836 129.421
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 6.188364526253e+02, best bound 6.398790484981e+02, gap 3.4003%
# watch 345
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0xa88a4a50
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 3e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 674 rows and 388 columns
# Presolve time: 0.00s
# Presolved: 145 rows, 237 columns, 615 nonzeros
# Variable types: 190 continuous, 47 integer (47 binary)
# Found heuristic solution: objective 526.4297807
#
# Root relaxation: objective 1.437057e+03, 145 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1437.05696    0    5  526.42978 1437.05696   173%     -    0s
# H    0     0                    1423.1938667 1437.05696  0.97%     -    0s
#
# Explored 1 nodes (145 simplex iterations) in 0.15 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 1423.19 526.43
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.423193866701e+03, best bound 1.437056962822e+03, gap 0.9741%
# watch 346
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0xd4db2396
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 9e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 674 rows and 388 columns
# Presolve time: 0.00s
# Presolved: 145 rows, 237 columns, 615 nonzeros
# Variable types: 190 continuous, 47 integer (47 binary)
# Found heuristic solution: objective 316.8696565
#
# Root relaxation: objective 9.653235e+02, 156 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  965.32346    0    6  316.86966  965.32346   205%     -    0s
# H    0     0                     943.3786843  965.32346  2.33%     -    0s
#
# Explored 1 nodes (156 simplex iterations) in 0.13 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 943.379 316.87
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 9.433786843094e+02, best bound 9.653234560200e+02, gap 2.3262%
# watch 347
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0x5dd820bc
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 1e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 674 rows and 388 columns
# Presolve time: 0.00s
# Presolved: 145 rows, 237 columns, 615 nonzeros
# Variable types: 190 continuous, 47 integer (47 binary)
# Found heuristic solution: objective 435.0643356
#
# Root relaxation: objective 1.182459e+03, 166 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1182.45871    0    7  435.06434 1182.45871   172%     -    0s
# H    0     0                    1151.1474342 1182.45871  2.72%     -    0s
#
# Explored 1 nodes (166 simplex iterations) in 0.14 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 1151.15 435.064
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.151147434209e+03, best bound 1.182458705569e+03, gap 2.7200%
# watch 348
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0x6ce0241e
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 9e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 673 rows and 385 columns
# Presolve time: 0.00s
# Presolved: 146 rows, 240 columns, 623 nonzeros
# Variable types: 192 continuous, 48 integer (48 binary)
# Found heuristic solution: objective 26.4116136
#
# Root relaxation: objective 6.325243e+02, 154 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  632.52427    0    1   26.41161  632.52427  2295%     -    0s
# H    0     0                     632.5201247  632.52427  0.00%     -    0s
#
# Explored 1 nodes (154 simplex iterations) in 0.12 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 632.52 26.4116
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 6.325201247450e+02, best bound 6.325242704004e+02, gap 0.0007%
# watch 349
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0x461681a9
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [3e-02, 1e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 674 rows and 388 columns
# Presolve time: 0.00s
# Presolved: 145 rows, 237 columns, 615 nonzeros
# Variable types: 190 continuous, 47 integer (47 binary)
# Found heuristic solution: objective 412.4521260
#
# Root relaxation: objective 1.018213e+03, 155 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1018.21345    0    4  412.45213 1018.21345   147%     -    0s
# H    0     0                    1002.4920659 1018.21345  1.57%     -    0s
#
# Explored 1 nodes (155 simplex iterations) in 0.11 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 1002.49 412.452
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 1.002492065859e+03, best bound 1.018213449716e+03, gap 1.5682%
# watch 350
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0xc32e2f92
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 9e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 673 rows and 385 columns
# Presolve time: 0.00s
# Presolved: 146 rows, 240 columns, 623 nonzeros
# Variable types: 192 continuous, 48 integer (48 binary)
# Found heuristic solution: objective 175.3768407
#
# Root relaxation: objective 8.260205e+02, 129 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  826.02054    0    4  175.37684  826.02054   371%     -    0s
# H    0     0                     810.7074287  826.02054  1.89%     -    0s
#
# Explored 1 nodes (129 simplex iterations) in 0.13 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 810.707 175.377
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 8.107074286958e+02, best bound 8.260205391889e+02, gap 1.8889%
# watch 351
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0x58c67250
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 9e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 673 rows and 385 columns
# Presolve time: 0.00s
# Presolved: 146 rows, 240 columns, 623 nonzeros
# Variable types: 192 continuous, 48 integer (48 binary)
# Found heuristic solution: objective 155.9055479
#
# Root relaxation: objective 7.908214e+02, 133 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  790.82140    0    3  155.90555  790.82140   407%     -    0s
# H    0     0                     788.6624379  790.82140  0.27%     -    0s
#
# Explored 1 nodes (133 simplex iterations) in 0.13 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 788.662 155.906
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 7.886624379398e+02, best bound 7.908213950988e+02, gap 0.2737%
# watch 352
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0xabdd587b
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [7e-04, 9e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 674 rows and 388 columns
# Presolve time: 0.00s
# Presolved: 145 rows, 237 columns, 615 nonzeros
# Variable types: 190 continuous, 47 integer (47 binary)
# Found heuristic solution: objective 139.7640077
#
# Root relaxation: objective 6.459519e+02, 150 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  645.95186    0    8  139.76401  645.95186   362%     -    0s
# H    0     0                     608.9932937  645.95186  6.07%     -    0s
#
# Explored 1 nodes (150 simplex iterations) in 0.15 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 608.993 139.764
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 6.089932937262e+02, best bound 6.459518639360e+02, gap 6.0688%
# watch 353
# Set parameter MIPGap to value 0.1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i9-12900H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Academic license 2496215 - for non-commercial use only - registered to an___@nus.edu.sg
# Optimize a model with 819 rows, 625 columns and 2017 nonzeros
# Model fingerprint: 0x81c31b51
# Variable types: 529 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 9e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 4e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 674 rows and 388 columns
# Presolve time: 0.00s
# Presolved: 145 rows, 237 columns, 615 nonzeros
# Variable types: 190 continuous, 47 integer (47 binary)
# Found heuristic solution: objective 281.4884776
#
# Root relaxation: objective 8.345638e+02, 139 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  834.56382    0    4  281.48848  834.56382   196%     -    0s
# H    0     0                     828.3772297  834.56382  0.75%     -    0s
#
# Explored 1 nodes (139 simplex iterations) in 0.15 seconds (0.00 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 2: 828.377 281.488
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 8.283772297271e+02, best bound 8.345638208544e+02, gap 0.7468%
# 523568.59633555816

# %%
revenue_data = pd.Series()
revenue_data.loc['Arbitrage'] = arbitrage/num_slices * 365
revenue_data.loc['Regulation'] = regulation/num_slices * 365
revenue_data.loc['Primary Reserve'] = preserve/num_slices * 365
revenue_data.loc['Contingency Reserve'] = creserve/num_slices * 365

pd.DataFrame(revenue_data, columns = ['revenue'])
# Out:
#                            revenue
# Arbitrage            119503.649473
# Regulation           418462.084499
# Primary Reserve          15.079196
# Contingency Reserve    1856.863844

# %%
df_filtered = revenue_data[revenue_data.values > 0]

fig = go.Figure(data=[go.Pie(labels=df_filtered.index, values=df_filtered.values, hole=0.3)])

# Update layout for the pie chart
fig.update_layout(
    title_text='Breakdown of Annual Revenues',
    annotations=[dict(text=' ', x=0.5, y=0.5, font_size=20, showarrow=False)]
)

# Display the plot in a notebook or interactive environment
fig.show()

# %%
# Create a DataFrame for the results
data = {
    'time': price_df.index[:len(all_charging_schedules)],
    'charge': all_charging_schedules,
    'discharge': all_discharging_schedules,
    'reg_down': all_reg_down_schedules,
    'reg_up': all_reg_up_schedules,
    'pres': all_pres_schedules,
    'cres': all_cres_schedules,
    'soc': all_soc_schedules
}

result_df = pd.DataFrame(data)

#result_df = result_df.set_index(['t'])

result_df['net_discharge'] = result_df['discharge'] - result_df['charge']
result_df['soc_percent'] = result_df['soc'] /cap_energy

result_df
# Out:
#                      time  charge  discharge  reg_down    reg_up  pres  cres  \
# 0     2023-01-01 00:00:00     0.0   1.000000  0.000000  0.000000   0.0   0.0
# 1     2023-01-01 00:30:00     0.0   0.218007  0.000000  0.781993   0.0   0.0
# 2     2023-01-01 01:00:00     0.0   0.000000  0.000000  0.000000   1.0   0.0
# 3     2023-01-01 01:30:00     0.0   0.000000  0.000000  0.000000   1.0   0.0
# 4     2023-01-01 02:00:00     0.0   0.000000  0.000000  0.000000   0.0   1.0
# ...                   ...     ...        ...       ...       ...   ...   ...
# 16987 2023-12-20 21:30:00     0.0   0.000000  1.000000  0.000000   0.0   0.0
# 16988 2023-12-20 22:00:00     0.0   0.000000  1.000000  0.000000   0.0   0.0
# 16989 2023-12-20 22:30:00     0.0   0.000000  1.000000  0.000000   0.0   0.0
# 16990 2023-12-20 23:00:00     0.0   0.247184  0.000000  0.752816   0.0   0.0
# 16991 2023-12-20 23:30:00     0.0   0.000000  0.008296  0.000000   0.0   0.0
#
#             soc  net_discharge  soc_percent
# 0      2.000000       1.000000     0.500000
# 1      1.443444       0.218007     0.360861
# 2      1.256442       0.000000     0.314110
# 3      1.255813       0.000000     0.313953
# 4      1.255185       0.000000     0.313796
# ...         ...            ...          ...
# 16987  1.120000       0.000000     0.280000
# 16988  1.186940       0.000000     0.296735
# 16989  1.253847       0.000000     0.313462
# 16990  1.320720       0.247184     0.330180
# 16991  1.120000       0.000000     0.280000
#
# [16992 rows x 10 columns]

# %%
result_df.tail()
# Out:
#                      time  charge  discharge  reg_down    reg_up  pres  cres  \
# 16987 2023-12-20 21:30:00     0.0   0.000000  1.000000  0.000000   0.0   0.0
# 16988 2023-12-20 22:00:00     0.0   0.000000  1.000000  0.000000   0.0   0.0
# 16989 2023-12-20 22:30:00     0.0   0.000000  1.000000  0.000000   0.0   0.0
# 16990 2023-12-20 23:00:00     0.0   0.247184  0.000000  0.752816   0.0   0.0
# 16991 2023-12-20 23:30:00     0.0   0.000000  0.008296  0.000000   0.0   0.0
#
#             soc  net_discharge  soc_percent
# 16987  1.120000       0.000000     0.280000
# 16988  1.186940       0.000000     0.296735
# 16989  1.253847       0.000000     0.313462
# 16990  1.320720       0.247184     0.330180
# 16991  1.120000       0.000000     0.280000

# %%
price_df.index.names = ['time']
price_data_ex = price_df.reset_index().to_json(orient='records', date_format='iso')
result_data_ex = result_df.to_json(orient='records', date_format='iso')

# %%
from scripts.result_export import generate_html

BESS_icost = 207
BESS_ecost = 355
BESS_pcost = 153

annual_revenue = total_revenue/num_slices * 365
discount_rate = 0.05
om_percentage = 0.05

generate_html(filename, BESS_icost, BESS_ecost, BESS_pcost, cap_energy, cap_power, annual_revenue, price_data_ex, result_data_ex, revenue_data, discount_rate, om_percentage, calendar_life)
# Out:
# HTML file generated:test.html

# %%
initial_cost
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 initial_cost
#
# NameError: name 'initial_cost' is not defined

# %%
BESS_icost = 207000
BESS_ecost = 355000
BESS_pcost = 153000

initial_cost = 207000 + 355000 * cap_energy + 153000*cap_power
annual_cost = initial_cost * 0.05
annual_revenue = total_revenue/num_slices * 365
discount_rate = 0.05
om_percentage = 0.05

# %%
initial_cost

# %%
annual_cost

# %% [markdown]
# # Plot

# %%
df = result_df
df = df.set_index(['time'])

#df['d'] = df['time'].dt.date
#df['t'] = df['time'].dt.time
#df = df.set_index(['d', 't']).drop(columns = ['time'])

# %%
start_time = 0
end_time = 48

# Create price figure
fig_price = go.Figure()
fig_price.add_trace(go.Scatter(x=price_df[start_time:end_time].index, y=price_df['arb_energy_price'], mode='lines', name='Energy'))
fig_price.add_trace(go.Scatter(x=price_df[start_time:end_time].index, y=price_df['reg_up_price'], mode='lines', name='Regulation Up'))
fig_price.add_trace(go.Scatter(x=price_df[start_time:end_time].index, y=price_df['reg_down_price'], mode='lines', name='Regulation Down'))
fig_price.add_trace(go.Scatter(x=price_df[start_time:end_time].index, y=price_df['pres_capacity_price'], mode='lines', name='Primary Reserve'))
fig_price.add_trace(go.Scatter(x=price_df[start_time:end_time].index, y=price_df['cres_capacity_price'], mode='lines', name='Contingency Reserve'))

fig_price.update_layout(
    title='Prices',
    xaxis_title='Time',
    yaxis_title='$/MWh',
    legend=dict(
        orientation='h',
        x=0,
        y=1.1
    ),
    autosize=True,
    margin=dict(l=40, r=40, t=80, b=40),
)

# Create charging and discharging figure
fig_charge_discharge = go.Figure()
fig_charge_discharge.add_trace(go.Scatter(x=result_df[start_time:end_time].index, y=result_df['net_discharge'], mode='lines', name='Net Power Discharge'))
fig_charge_discharge.add_trace(go.Scatter(x=result_df[start_time:end_time].index, y=result_df['reg_up'], mode='lines', name='Regulation Up'))
fig_charge_discharge.add_trace(go.Scatter(x=result_df[start_time:end_time].index, y=result_df['reg_down'], mode='lines', name='Regulation Down'))
fig_charge_discharge.add_trace(go.Scatter(x=result_df[start_time:end_time].index, y=result_df['pres'], mode='lines', name='Primary Reserve'))
fig_charge_discharge.add_trace(go.Scatter(x=result_df[start_time:end_time].index, y=result_df['cres'], mode='lines', name='Contingency Reserve'))

fig_charge_discharge.update_layout(
    title='Charging and Discharging Schedule',
    xaxis_title='Time',
    yaxis_title='Power (MW)',
    legend=dict(
        orientation='h',
        x=0,
        y=1.1
    ),
    autosize=True,
    margin=dict(l=40, r=40, t=80, b=40),
)

# Create state of charge figure
fig_soc = go.Figure()
fig_soc.add_trace(go.Scatter(x=result_df.index[start_time:end_time], y=result_df['soc_percent']*100, mode='lines', name='net', line=dict(color='orange')))
fig_soc.update_layout(
    title='State of Charge',
    xaxis_title='Time',
    yaxis_title='SOC (%)',
    legend=dict(
        orientation='h',
        x=0,
        y=1.1
    ),
    autosize=True,
    margin=dict(l=40, r=40, t=80, b=40),
)

# Generate HTML snippets for each figure
price_html = pio.to_html(fig_price, full_html=False)
charge_discharge_html = pio.to_html(fig_charge_discharge, full_html=False)
soc_html = pio.to_html(fig_soc, full_html=False)

# Combine all HTML snippets into a single HTML document
full_html = f"""
<!DOCTYPE html>
<html>
<head>
    <meta charset="UTF-8">
    <title>Figures</title>
    <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
</head>
<body>
    <h1>Price Figure</h1>
    {price_html}
    <h1>Charging and Discharging Schedule</h1>
    {charge_discharge_html}
    <h1>State of Charge</h1>
    {soc_html}
</body>
</html>
"""

# Save to an HTML file
with open("result/day/" + filename + ".html", "w",  encoding="utf-8") as file:
    file.write(full_html)
