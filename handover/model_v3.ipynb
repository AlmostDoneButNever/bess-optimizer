# %%
from pyomo.environ import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from scripts.data_import import data_import
from scripts.run_optimization_model import run_model

# %% [markdown]
# # Read Data

# %%
file = 'data_s3'
path = 'data/' + file + '.xlsx'
data, basis, bess, service, revenue_change = data_import(path)
# Out:
# /Users/angelmah/Documents/codes/bess-optimizer/handover/scripts/data_import.py:13: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['basis']  = data['basis'].dropna().drop(['Tag']).replace({'YES': 1, 'NO': 0})
# /Users/angelmah/Documents/codes/bess-optimizer/handover/scripts/data_import.py:16: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['bess']  = data['bess'].dropna().drop(['Tag', np.nan]).replace({'YES': 1, 'NO': 0})

# %% [markdown]
# # Base case simulation

# %%
# Override Excel settings (if required)
# bess['cap_power'] = 1
# bess['cap_energy'] = 4
bess['s_eff'] = 1

# Model optimality gap and time limits, solving process will stop when any of the conditions are satisfied
model_optimality_gap = 0.005     # proximity to optimal solution, 0.01 means 1% difference with the optimal solution
model_time_limit = 100          # seconds

# Result file name
result_html_name = "result"
result_html_path = "results/" + result_html_name

# Run model
packaged_data = [data, basis, bess, service] 
annual_revenue, result_df, revenue_df, financial_metrics = run_model(packaged_data, result_html_path, model_optimality_gap = model_optimality_gap, model_time_limit = model_time_limit)
[NPV, ROI, IRR, BCR, PP] = financial_metrics
# Out:
# HTML file generated:results/result.html

# %% [markdown]
# # Sensitivity analysis

# %%
power_range = list(range(1, 16))
energy_range = list(range(1, 16))

econs_sens_keys = []
econs_sens_values = []

for power in power_range:
    for energy in energy_range:

        power_target = power * 0.5
        energy_target = energy * 0.5

        print("Solving: ", power_target, energy_target)

        bess['cap_power'] = power_target
        bess['cap_energy'] = energy_target

        packaged_data = [data, basis, bess, service] 
        annual_revenue, result_df, revenue_df, financial_metrics = run_model(packaged_data, result_html_name = [])
        [NPV, ROI, IRR, BCR, PP] = financial_metrics

        econs_sens_keys.append([power_target, energy_target])
        econs_sens_values.append([annual_revenue] + financial_metrics)

df = pd.DataFrame(index = pd.MultiIndex.from_tuples(econs_sens_keys, names = ['Power', 'Energy']), data = econs_sens_values, columns = ['annual_revenue', 'NPV', 'ROI', 'IRR', 'BCR', 'PP'])
df['annual_revenue_per_kw'] = df['annual_revenue']/df.index.get_level_values(0)/1000
df = df.reset_index()
df

# Export result to excel
df.to_excel("results/sens_result.xlsx")
# Out:
# Solving:  0.5 0.5
# Solving:  0.5 1.0
# Solving:  0.5 1.5
# Solving:  0.5 2.0
# Solving:  0.5 2.5
# Solving:  0.5 3.0
# Solving:  0.5 3.5
# Solving:  0.5 4.0
# Solving:  0.5 4.5
# Solving:  0.5 5.0
# Solving:  0.5 5.5
# Solving:  0.5 6.0
# Solving:  0.5 6.5
# Solving:  0.5 7.0
# Solving:  0.5 7.5
# Solving:  1.0 0.5
# Solving:  1.0 1.0
# Solving:  1.0 1.5
# Solving:  1.0 2.0
# Solving:  1.0 2.5
# Solving:  1.0 3.0
# Solving:  1.0 3.5
# Solving:  1.0 4.0
# Solving:  1.0 4.5
# Solving:  1.0 5.0
# Solving:  1.0 5.5
# Solving:  1.0 6.0
# Solving:  1.0 6.5
# Solving:  1.0 7.0
# Solving:  1.0 7.5
# Solving:  1.5 0.5
# Solving:  1.5 1.0
# Solving:  1.5 1.5
# Solving:  1.5 2.0
# Solving:  1.5 2.5
# Solving:  1.5 3.0
# Solving:  1.5 3.5
# Solving:  1.5 4.0
# Solving:  1.5 4.5
# Solving:  1.5 5.0
# Solving:  1.5 5.5
# Solving:  1.5 6.0
# Solving:  1.5 6.5
# Solving:  1.5 7.0
# Solving:  1.5 7.5
# Solving:  2.0 0.5
# Solving:  2.0 1.0
# Solving:  2.0 1.5
# Solving:  2.0 2.0
# Solving:  2.0 2.5
# Solving:  2.0 3.0
# Solving:  2.0 3.5
# Solving:  2.0 4.0
# Solving:  2.0 4.5
# Solving:  2.0 5.0
# Solving:  2.0 5.5
# Solving:  2.0 6.0
# Solving:  2.0 6.5
# Solving:  2.0 7.0
# Solving:  2.0 7.5
# Solving:  2.5 0.5
# Solving:  2.5 1.0
# Solving:  2.5 1.5
# Solving:  2.5 2.0
# Solving:  2.5 2.5
# Solving:  2.5 3.0
# Solving:  2.5 3.5
# Solving:  2.5 4.0
# Solving:  2.5 4.5
# Solving:  2.5 5.0
# Solving:  2.5 5.5
# Solving:  2.5 6.0
# Solving:  2.5 6.5
# Solving:  2.5 7.0
# Solving:  2.5 7.5
# Solving:  3.0 0.5
# Solving:  3.0 1.0
# Solving:  3.0 1.5
# Solving:  3.0 2.0
# Solving:  3.0 2.5
# Solving:  3.0 3.0
# Solving:  3.0 3.5
# Solving:  3.0 4.0
# Solving:  3.0 4.5
# Solving:  3.0 5.0
# Solving:  3.0 5.5
# Solving:  3.0 6.0
# Solving:  3.0 6.5
# Solving:  3.0 7.0
# Solving:  3.0 7.5
# Solving:  3.5 0.5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 19
#      16 bess['cap_energy'] = energy_target
#      18 packaged_data = [data, basis, bess, service]
# ---> 19 annual_revenue, result_df, revenue_df, financial_metrics = run_model(packaged_data, result_html_name = [])
#      20 [NPV, ROI, IRR, BCR, PP] = financial_metrics
#      22 econs_sens_keys.append([power_target, energy_target])
#
# File ~/Documents/codes/bess-optimizer/handover/scripts/run_optimization_model.py:68, in run_model(packaged_data, result_html_name, model_optimality_gap, model_time_limit)
#      65     periodic_load = []
#      67 # try:
# ---> 68 model, revenue, schedule_dict, revenue_dict = optimize_revenue(initial_soc, packaged_data, periodic_price, periodic_load, final_soc_target=0, cap_settings = [], model_optimality_gap = model_optimality_gap, model_time_limit = model_time_limit)
#      70 # Store the results
#      71 total_revenue += model.obj()
#
# File ~/Documents/codes/bess-optimizer/handover/scripts/optimization_model.py:289, in optimize_revenue(initial_soc, data_input, prices, loads, final_soc_target, cap_settings, model_optimality_gap, model_time_limit)
#     286 solver.options['mipgap'] = model_optimality_gap
#     287 solver.options['tmlim'] = model_time_limit
# --> 289 results = solver.solve(model, tee=False)
#     291 schedule_dict = {}
#     292 revenue_dict = {}
#
# File ~/Documents/codes/bess-optimizer/handover/.venv/lib/python3.12/site-packages/pyomo/opt/base/solvers.py:598, in OptSolver.solve(self, *args, **kwds)
#     594 try:
#     595     # we're good to go.
#     596     initial_time = time.time()
# --> 598     self._presolve(*args, **kwds)
#     600     presolve_completion_time = time.time()
#     601     if self._report_timing:
#
# File ~/Documents/codes/bess-optimizer/handover/.venv/lib/python3.12/site-packages/pyomo/opt/solver/shellcmd.py:223, in SystemCallSolver._presolve(self, *args, **kwds)
#     220 self._keepfiles = kwds.pop("keepfiles", False)
#     221 self._define_signal_handlers = kwds.pop('use_signal_handling', None)
# --> 223 OptSolver._presolve(self, *args, **kwds)
#     225 #
#     226 # Verify that the input problems exists
#     227 #
#     228 for filename in self._problem_files:
#
# File ~/Documents/codes/bess-optimizer/handover/.venv/lib/python3.12/site-packages/pyomo/opt/base/solvers.py:704, in OptSolver._presolve(self, *args, **kwds)
#     701 if self._problem_format:
#     702     write_start_time = time.time()
#     703     (self._problem_files, self._problem_format, self._smap_id) = (
# --> 704         self._convert_problem(
#     705             args, self._problem_format, self._valid_problem_formats, **kwds
#     706         )
#     707     )
#     708     total_time = time.time() - write_start_time
#     709     if self._report_timing:
#
# File ~/Documents/codes/bess-optimizer/handover/.venv/lib/python3.12/site-packages/pyomo/opt/base/solvers.py:756, in OptSolver._convert_problem(self, args, problem_format, valid_problem_formats, **kwds)
#     755 def _convert_problem(self, args, problem_format, valid_problem_formats, **kwds):
# --> 756     return convert_problem(
#     757         args, problem_format, valid_problem_formats, self.has_capability, **kwds
#     758     )
#
# File ~/Documents/codes/bess-optimizer/handover/.venv/lib/python3.12/site-packages/pyomo/opt/base/convert.py:97, in convert_problem(args, target_problem_type, valid_problem_types, has_capability, **kwds)
#      95                 tmpkw = kwds
#      96                 tmpkw['capabilities'] = has_capability
# ---> 97                 problem_files, symbol_map = converter.apply(*tmp, **tmpkw)
#      98                 return problem_files, ptype, symbol_map
#     100 msg = 'No conversion possible.  Source problem type: %s.  Valid target types: %s'
#
# File ~/Documents/codes/bess-optimizer/handover/.venv/lib/python3.12/site-packages/pyomo/solvers/plugins/converter/model.py:78, in PyomoMIPConverter.apply(self, *args, **kwds)
#      70         symbol_map_id = instance.write(
#      71             problem_filename,
#      72             format=ProblemFormat.cpxlp,
#    (...)
#      75             **io_options
#      76         )
#      77     else:
# ---> 78         (problem_filename, symbol_map_id) = instance.write(
#      79             filename=problem_filename,
#      80             format=ProblemFormat.cpxlp,
#      81             solver_capability=capabilities,
#      82             io_options=io_options,
#      83         )
#      84     return (problem_filename,), symbol_map_id
#      85 else:
#      86     #
#      87     # I'm simply exposing a fatal issue with
#    (...)
#      90     # arguments that can be sent to the writer?
#      91     #
#
# File ~/Documents/codes/bess-optimizer/handover/.venv/lib/python3.12/site-packages/pyomo/core/base/block.py:1916, in BlockData.write(self, filename, format, solver_capability, io_options, int_marker)
#    1913     def solver_capability(x):
#    1914         return True
# -> 1916 (filename, smap) = problem_writer(self, filename, solver_capability, io_options)
#    1917 smap_id = id(smap)
#    1918 if not hasattr(self, 'solutions'):
#    1919     # This is a bit of a hack.  The write() method was moved
#    1920     # here from PyomoModel to support the solution of arbitrary
#    (...)
#    1925     # dependency (we only need it here because we store the
#    1926     # SymbolMap returned by the writer in the solutions).
#
# File ~/Documents/codes/bess-optimizer/handover/.venv/lib/python3.12/site-packages/pyomo/repn/plugins/lp_writer.py:208, in LPWriter.__call__(self, model, filename, solver_capability, io_options)
#     205     io_options['allow_quadratic_constraint'] = qc
#     207 with open(filename, 'w', newline='') as FILE:
# --> 208     info = self.write(model, FILE, **io_options)
#     209 return filename, info.symbol_map
#
# File ~/Documents/codes/bess-optimizer/handover/.venv/lib/python3.12/site-packages/pyomo/repn/plugins/lp_writer.py:241, in LPWriter.write(self, model, ostream, **options)
#     237 # Pause the GC, as the walker that generates the compiled LP
#     238 # representation generates (and disposes of) a large number of
#     239 # small objects.
#     240 with PauseGC():
# --> 241     return _LPWriter_impl(ostream, config).write(model)
#
# File ~/Documents/codes/bess-optimizer/handover/.venv/lib/python3.12/site-packages/pyomo/repn/plugins/lp_writer.py:414, in _LPWriter_impl.write(self, model)
#     410     last_parent = con.parent_component()
#     411 # Note: Constraint.to_bounded_expression(evaluate_bounds=True)
#     412 # guarantee a return value that is either a (finite)
#     413 # native_numeric_type, or None
# --> 414 lb, body, ub = con.to_bounded_expression(True)
#     416 if lb is None and ub is None:
#     417     # Note: you *cannot* output trivial (unbounded)
#     418     # constraints in LP format.  I suppose we could add a
#     419     # slack variable if skip_trivial_constraints is False,
#     420     # but that seems rather silly.
#     421     continue
#
# File ~/Documents/codes/bess-optimizer/handover/.venv/lib/python3.12/site-packages/pyomo/core/base/constraint.py:245, in ConstraintData.to_bounded_expression(self, evaluate_bounds)
#     243         ans = lhs, rhs, lhs if expr.__class__ is EqualityExpression else None
#     244     else:
# --> 245         ans = 0 if expr.__class__ is EqualityExpression else None, lhs - rhs, 0
#     247 if evaluate_bounds:
#     248     lb, body, ub = ans
#
# File ~/Documents/codes/bess-optimizer/handover/.venv/lib/python3.12/site-packages/pyomo/core/expr/numeric_expr.py:441, in NumericValue.__sub__(self, other)
#     433 def __sub__(self, other):
#     434     """
#     435     Binary subtraction
#     436
#    (...)
#     439         self - other
#     440     """
# --> 441     return self.__add__(-other)
#
# File ~/Documents/codes/bess-optimizer/handover/.venv/lib/python3.12/site-packages/pyomo/core/expr/numeric_expr.py:431, in NumericValue.__add__(self, other)
#     423 def __add__(self, other):
#     424     """
#     425     Binary addition
#     426
#    (...)
#     429         self + other
#     430     """
# --> 431     return _add_dispatcher[self.__class__, other.__class__](self, other)
#
# File ~/Documents/codes/bess-optimizer/handover/.venv/lib/python3.12/site-packages/pyomo/core/expr/numeric_expr.py:2014, in _add_var_other(a, b)
#    2013 def _add_var_other(a, b):
# -> 2014     return SumExpression([a, b])
#
# File ~/Documents/codes/bess-optimizer/handover/.venv/lib/python3.12/site-packages/pyomo/core/expr/numeric_expr.py:1147, in SumExpression.__init__(self, args)
#    1144 __slots__ = ('_nargs',)
#    1145 PRECEDENCE = 6
# -> 1147 def __init__(self, args):
#    1148     # unlike other expressions, we expect (require) args to be a list
#    1149     if args.__class__ is not list:
#    1150         args = list(args)
#
# KeyboardInterrupt:

# %%
# Calculating Energy/Power ratio for the contour plot
df['Ratio'] = df['Energy'] / df['Power']
pivot_df = df.pivot(index="Energy", columns="Power", values="NPV") * 100
pivot_ratio = df.pivot(index="Energy", columns="Power", values="Ratio")

# Data for the heatmap
z = pivot_df.values
x = pivot_df.columns
y = pivot_df.index

# Creating the heatmap with contour lines
fig = go.Figure()

# Add heatmap
fig.add_trace(go.Heatmap(
    z=z,
    x=x,
    y=y,
    colorscale='RdBu',
    reversescale=True,  # High values red, low values blue
    colorbar=dict(title='ROI (%)'),
    zmin=np.min(z),  # Define the range of z for better contrast
    zmax=np.max(z)
))

# Add contour lines for the Energy/Power ratio with text labels
fig.add_trace(go.Contour(
    z=pivot_ratio.values,
    x=pivot_df.columns,
    y=pivot_df.index,
    showscale=False,  # Hide the scale for contour lines
    contours=dict(
        coloring='lines',
        showlabels=True,  # Enable labels on contours
        labelfont=dict(size=12, color='black'),  # Customize the font of the labels
        start=0.5,  # Starting value for contour lines
        end=4,     # Ending value for contour lines
        size=0.5   # Interval between contour lines
    ),
    line=dict(color='black', width=2),
    # ncontours=50  # Increase the number of contour lines

))

# Adding titles and labels, and setting axis ranges to start from 1
fig.update_layout(
    title='Heatmap of ROI with Energy/Power Ratio Contour Lines',
    xaxis=dict(title='Power', range=[0.5, 8]),
    yaxis=dict(title='Energy', range=[0.5, 8])
)

# Display the figure
fig.show()
